# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %pylab inline
from bokeh.core.properties import value
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.palettes import Spectral6, Spectral8, Category20
from bokeh.transform import factor_cmap

output_notebook()

cust = pd.read_csv('C:/Users/Lara/Documents/Repository/Capstone2/custodial-deaths.csv')
shoot = pd.read_csv('C:/Users/Lara/Documents/Repository/Capstone2/officer_shootings.csv')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Lara\Miniconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['show', 'figure', 'source']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8480e3e9-a4a0-44a0-8ba5-e628019f7589">Loading BokehJS ...</span>
#     </div>

# %%
deathtype= list(cust['Manner Death'].unique())

# %%
eth = list(cust['Ethnicity'].unique())

# %%
breakdown = cust.groupby(['Ethnicity', 'Manner Death'])['Last Name'].count()
death_eth_df = breakdown.unstack()
death_eth_df = death_eth_df.fillna(0).astype(int)
death_eth_df
# Out:
# Manner Death                      Accidental injury caused by others  \
# Ethnicity
# American Indian/Alaska Native                                      0
# Anglo or White                                                     3
# Asian                                                              0
# Black or African American                                          6
# Hispanic or Latino                                                11
# Middle East                                                        0
# Native Hawaiian/Pacific Islander                                   1
# Other/Don't Know                                                   0
#
# Manner Death                      Accidental injury to self  \
# Ethnicity
# American Indian/Alaska Native                             0
# Anglo or White                                           63
# Asian                                                     0
# Black or African American                                36
# Hispanic or Latino                                       54
# Middle East                                               1
# Native Hawaiian/Pacific Islander                          0
# Other/Don't Know                                          1
#
# Manner Death                      Alcohol/Drug Intoxication  \
# Ethnicity
# American Indian/Alaska Native                             0
# Anglo or White                                           99
# Asian                                                     3
# Black or African American                                93
# Hispanic or Latino                                       88
# Middle East                                               0
# Native Hawaiian/Pacific Islander                          1
# Other/Don't Know                                          0
#
# Manner Death                      Homicide by Law Enforcement/Correctional Staff  \
# Ethnicity
# American Indian/Alaska Native                                                  5
# Anglo or White                                                               321
# Asian                                                                          5
# Black or African American                                                    213
# Hispanic or Latino                                                           291
# Middle East                                                                    7
# Native Hawaiian/Pacific Islander                                               1
# Other/Don't Know                                                              35
#
# Manner Death                      Homicide by Other  Natural Causes/Illness  \
# Ethnicity
# American Indian/Alaska Native                     0                       5
# Anglo or White                                   25                    2183
# Asian                                             1                      19
# Black or African American                        22                    1687
# Hispanic or Latino                               24                    1363
# Middle East                                       0                       2
# Native Hawaiian/Pacific Islander                  0                       1
# Other/Don't Know                                  0                       6
#
# Manner Death                      Other  Suicide
# Ethnicity
# American Indian/Alaska Native         1        2
# Anglo or White                       77      455
# Asian                                 0        6
# Black or African American            68      147
# Hispanic or Latino                   56      229
# Middle East                           0        2
# Native Hawaiian/Pacific Islander      0        1
# Other/Don't Know                      1        2

# %%
data= {'Ethnicity': eth, 'Accidental injury by others' : list(death_eth_df['Accidental injury caused by others']), 
       'Natural Causes': list(death_eth_df['Natural Causes/Illness']),  'Other':list(death_eth_df['Other']), 
       'Accidental injury to self': list(death_eth_df['Accidental injury to self']),  
       'Homicide by Law Enforcement/Correctional Staff': list(death_eth_df['Homicide by Law Enforcement/Correctional Staff']),
       'Suicide': list(death_eth_df['Suicide']), 'Alcohol/Drug Intoxication': list(death_eth_df['Alcohol/Drug Intoxication']), 'Homicide by Other': list(death_eth_df['Homicide by Other'])}

source = ColumnDataSource(data=data)

g = figure(x_range=eth, plot_height=250, title="Manner of Death by Ethnicity",
           toolbar_location=None, tools="")


g.vbar_stack(deathtype, x= 'Ethnicity', width=0.9, color=Spectral8, source=source,
             legend=[value(x) for x in deathtype])

g.y_range.start = 0
g.y_range.end = 6000
g.x_range.range_padding = 0.1
g.xgrid.grid_line_color = None
g.axis.minor_tick_line_color = None
g.outline_line_color = None
g.legend.location = "top_left"
g.legend.orientation = "horizontal"

show(g)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3aa6002f-a0e3-4693-a549-f6c34d190724"></div>
# </div>
